# %%
import pandas as pd

contaminacaoXrenda = pd.read_csv("../resultados/pb-05-contaminacaoXrenda.csv", sep=';')

# renomeando colunas
novos_nomes = {
    "UF": "Estado",
    "B0011": "Febre",
    "B0012": "Tosse",
    "B0013": "Dor de garganta",
    "B0014": "Dificuldade de respirar",
    "B0015": "Dor de cabeca",
    "B0016": "Dor no peito",
    "B0017": "Nausea",
    "B0018": "Nariz entupido ou escorrendo",
    "B0019": "Fadiga",
    "B00110": "Dor nos olhos",
    "B00111": "Perda de cheiro ou sabor",
    "B00112": "Dor muscular",
    "C01011": "Faixa de renda",
    "C01012": "Valor em dinheiro"
}

result = contaminacaoXrenda.rename(columns=novos_nomes)

result["Faixa de renda"] = result["Faixa de renda"]\
    .replace({
        0: "0 - 100",
        1: "101 - 300",
        2: "301 - 600",
        3: "601 - 800",
        4: "801 - 1.600",
        5: "1.601 - 3.000",
        6: "3.001 - 10.000",
        7: "10.001 - 50.000",
        8: "50.001 - 100.000",
        9: "Mais de 100.000",
    })

result = result.replace({1: "Sim", 2: "Não", 3: "Não sabe", 9: "Ignorado", 25: "Paraíba"})

display(result)
# Out:
#        Estado Febre Tosse Dor de garganta Dificuldade de respirar  \
# 0     Paraíba   Não   Não             Não                     Não
# 1     Paraíba   Não   Não             Não                     Não
# 2     Paraíba   Não   Não             Não                     Não
# 3     Paraíba   Não   Não             Não                     Não
# 4     Paraíba   Não   Não             Não                     Não
# ...       ...   ...   ...             ...                     ...
# 8654  Paraíba   Não   Sim             Não                     Não
# 8655  Paraíba   Não   Não             Não                     Não
# 8656  Paraíba   Não   Não             Não                     Não
# 8657  Paraíba   Não   Não             Não                     Não
# 8658  Paraíba   Não   Não             Não                     Não
#
#      Dor de cabeca Dor no peito Nausea Nariz entupido ou escorrendo Fadiga  \
# 0              Não          Não    Não                          Não    Não
# 1              Não          Não    Não                          Não    Não
# 2              Não          Não    Não                          Não    Não
# 3              Não          Não    Não                          Não    Não
# 4              Não          Não    Não                          Não    Não
# ...            ...          ...    ...                          ...    ...
# 8654           Sim          Não    Não                          Não    Não
# 8655           Não          Não    Não                          Não    Não
# 8656           Não          Não    Não                          Não    Não
# 8657           Não          Não    Não                          Não    Não
# 8658           Não          Não    Não                          Não    Não
#
#      Dor nos olhos Perda de cheiro ou sabor Dor muscular Faixa de renda  \
# 0              Não                      Não          Não      101 - 300
# 1              Não                      Não          Não            NaN
# 2              Não                      Não          Não    801 - 1.600
# 3              Não                      Não          Não  1.601 - 3.000
# 4              Não                      Não          Não            NaN
# ...            ...                      ...          ...            ...
# 8654           Não                      Sim          Não            NaN
# 8655           Não                      Não          Não            NaN
# 8656           Não                      Não          Não      301 - 600
# 8657           Não                      Não          Não    801 - 1.600
# 8658           Não                      Não          Não            NaN
#
#       Valor em dinheiro
# 0                 160.0
# 1                   NaN
# 2                1570.0
# 3                2090.0
# 4                   NaN
# ...                 ...
# 8654                NaN
# 8655                NaN
# 8656              450.0
# 8657             1045.0
# 8658                NaN
#
# [8659 rows x 15 columns]

# %%
import pandasql as ps

query = """
SELECT
    "Faixa de renda",
    ROUND(100.0 * SUM(CASE WHEN Febre = 'Sim' THEN 1 ELSE 0 END) / COUNT(*), 2) AS "Febre Sim (%)",
    ROUND(100.0 * SUM(CASE WHEN Febre = 'Não' THEN 1 ELSE 0 END) / COUNT(*), 2) AS "Febre Não (%)",
    ROUND(100.0 * SUM(CASE WHEN Tosse = 'Sim' THEN 1 ELSE 0 END) / COUNT(*), 2) AS "Tosse Sim (%)",
    ROUND(100.0 * SUM(CASE WHEN Tosse = 'Não' THEN 1 ELSE 0 END) / COUNT(*), 2) AS "Tosse Não (%)",
    ROUND(100.0 * SUM(CASE WHEN "Dor de garganta" = 'Sim' THEN 1 ELSE 0 END) / COUNT(*), 2) AS "Dor de garganta Sim (%)",
    ROUND(100.0 * SUM(CASE WHEN "Dor de garganta" = 'Não' THEN 1 ELSE 0 END) / COUNT(*), 2) AS "Dor de garganta Não (%)",
    ROUND(100.0 * SUM(CASE WHEN "Dificuldade de respirar" = 'Sim' THEN 1 ELSE 0 END) / COUNT(*), 2) AS "Dificuldade de respirar Sim (%)",
    ROUND(100.0 * SUM(CASE WHEN "Dificuldade de respirar" = 'Não' THEN 1 ELSE 0 END) / COUNT(*), 2) AS "Dificuldade de respirar Não (%)",
    ROUND(100.0 * SUM(CASE WHEN "Dor de cabeca" = 'Sim' THEN 1 ELSE 0 END) / COUNT(*), 2) AS "Dor de cabeça Sim (%)",
    ROUND(100.0 * SUM(CASE WHEN "Dor de cabeca" = 'Não' THEN 1 ELSE 0 END) / COUNT(*), 2) AS "Dor de cabeça Não (%)",
    ROUND(100.0 * SUM(CASE WHEN "Dor no peito" = 'Sim' THEN 1 ELSE 0 END) / COUNT(*), 2) AS "Dor no peito Sim (%)",
    ROUND(100.0 * SUM(CASE WHEN "Dor no peito" = 'Não' THEN 1 ELSE 0 END) / COUNT(*), 2) AS "Dor no peito Não (%)",
    ROUND(100.0 * SUM(CASE WHEN Nausea = 'Sim' THEN 1 ELSE 0 END) / COUNT(*), 2) AS "Náusea Sim (%)",
    ROUND(100.0 * SUM(CASE WHEN Nausea = 'Não' THEN 1 ELSE 0 END) / COUNT(*), 2) AS "Náusea Não (%)",
    ROUND(100.0 * SUM(CASE WHEN "Nariz entupido ou escorrendo" = 'Sim' THEN 1 ELSE 0 END) / COUNT(*), 2) AS "Nariz entupido ou escorrendo Sim (%)",
    ROUND(100.0 * SUM(CASE WHEN "Nariz entupido ou escorrendo" = 'Não' THEN 1 ELSE 0 END) / COUNT(*), 2) AS "Nariz entupido ou escorrendo Não (%)",
    ROUND(100.0 * SUM(CASE WHEN Fadiga = 'Sim' THEN 1 ELSE 0 END) / COUNT(*), 2) AS "Fadiga Sim (%)",
    ROUND(100.0 * SUM(CASE WHEN Fadiga = 'Não' THEN 1 ELSE 0 END) / COUNT(*), 2) AS "Fadiga Não (%)",
    ROUND(100.0 * SUM(CASE WHEN "Dor nos olhos" = 'Sim' THEN 1 ELSE 0 END) / COUNT(*), 2) AS "Dor nos olhos Sim (%)",
    ROUND(100.0 * SUM(CASE WHEN "Dor nos olhos" = 'Não' THEN 1 ELSE 0 END) / COUNT(*), 2) AS "Dor nos olhos Não (%)",
    ROUND(100.0 * SUM(CASE WHEN "Perda de cheiro ou sabor" = 'Sim' THEN 1 ELSE 0 END) / COUNT(*), 2) AS "Perda de cheiro ou sabor Sim (%)",
    ROUND(100.0 * SUM(CASE WHEN "Perda de cheiro ou sabor" = 'Não' THEN 1 ELSE 0 END) / COUNT(*), 2) AS "Perda de cheiro ou sabor Não (%)",
    ROUND(100.0 * SUM(CASE WHEN "Dor muscular" = 'Sim' THEN 1 ELSE 0 END) / COUNT(*), 2) AS "Dor muscular Sim (%)",
    ROUND(100.0 * SUM(CASE WHEN "Dor muscular" = 'Não' THEN 1 ELSE 0 END) / COUNT(*), 2) AS "Dor muscular Não (%)"
FROM result
GROUP BY CASE "Faixa de renda"
    WHEN '0 - 100' THEN 1
    WHEN '101 - 300' THEN 2
    WHEN '301 - 600' THEN 3
    WHEN '601 - 800' THEN 4
    WHEN '801 - 1.600' THEN 5
    WHEN '1.601 - 3.000' THEN 6
    WHEN '3.001 - 10.000' THEN 7
    WHEN '10.001 - 50.000' THEN 8
    WHEN '50.001 - 100.000' THEN 9
    WHEN 'Mais de 100.000' THEN 10
    ELSE 0 -- Caso apareça alguma outra categoria
END;
"""
select = ps.sqldf(query, locals())

display(select)
# Out:
#     Faixa de renda  Febre Sim (%)  Febre Não (%)  Tosse Sim (%)  \
# 0             None           2.71          96.94           3.66
# 1          0 - 100          12.12          84.85           9.09
# 2        101 - 300           3.01          96.99           8.43
# 3        301 - 600           2.42          97.58           2.42
# 4        601 - 800           4.17          95.83           3.47
# 5      801 - 1.600           4.65          95.27           6.70
# 6    1.601 - 3.000           4.50          95.26           4.98
# 7   3.001 - 10.000           3.50          96.15           5.59
# 8  10.001 - 50.000           2.78          97.22           8.33
#
#    Tosse Não (%)  Dor de garganta Sim (%)  Dor de garganta Não (%)  \
# 0          95.99                     2.23                    97.31
# 1          87.88                     9.09                    87.88
# 2          91.57                     3.01                    96.99
# 3          97.58                     3.81                    96.19
# 4          96.53                     4.17                    95.83
# 5          93.30                     5.52                    94.48
# 6          94.55                     6.40                    93.36
# 7          94.06                     6.29                    93.36
# 8          91.67                     8.33                    91.67
#
#    Dificuldade de respirar Sim (%)  Dificuldade de respirar Não (%)  \
# 0                             0.90                            98.65
# 1                             6.06                            90.91
# 2                             1.20                            98.80
# 3                             1.04                            98.96
# 4                             0.69                            99.31
# 5                             1.81                            98.11
# 6                             2.61                            97.16
# 7                             3.15                            96.50
# 8                             2.78                            97.22
#
#    Dor de cabeça Sim (%)  ...  Nariz entupido ou escorrendo Sim (%)  \
# 0                   5.42  ...                                  3.66
# 1                  18.18  ...                                 12.12
# 2                  12.05  ...                                  5.42
# 3                   8.65  ...                                  5.88
# 4                   6.25  ...                                  4.17
# 5                   9.38  ...                                  5.75
# 6                  12.32  ...                                  7.35
# 7                  14.34  ...                                  8.74
# 8                   8.33  ...                                  8.33
#
#    Nariz entupido ou escorrendo Não (%)  Fadiga Sim (%)  Fadiga Não (%)  \
# 0                                 95.99            1.28           98.27
# 1                                 84.85            3.03           93.94
# 2                                 94.58            4.22           95.78
# 3                                 94.12            2.08           97.92
# 4                                 95.83            1.39           98.61
# 5                                 94.17            3.47           96.45
# 6                                 92.42            5.45           94.31
# 7                                 90.91            3.15           96.50
# 8                                 91.67            8.33           91.67
#
#    Dor nos olhos Sim (%)  Dor nos olhos Não (%)  \
# 0                   0.98                  98.24
# 1                  12.12                  84.85
# 2                   2.41                  97.59
# 3                   2.08                  97.58
# 4                   0.69                  99.31
# 5                   2.05                  97.64
# 6                   3.08                  96.21
# 7                   3.15                  96.50
# 8                   0.00                 100.00
#
#    Perda de cheiro ou sabor Sim (%)  Perda de cheiro ou sabor Não (%)  \
# 0                              1.28                             97.95
# 1                              9.09                             87.88
# 2                              2.41                             97.59
# 3                              2.08                             97.58
# 4                              1.39                             98.61
# 5                              3.31                             96.30
# 6                              2.84                             96.68
# 7                              3.50                             96.15
# 8                              0.00                            100.00
#
#    Dor muscular Sim (%)  Dor muscular Não (%)
# 0                  2.24                 96.99
# 1                 15.15                 81.82
# 2                  4.82                 95.18
# 3                  3.46                 96.19
# 4                  3.47                 95.83
# 5                  5.67                 93.85
# 6                  4.98                 94.55
# 7                  3.85                 95.80
# 8                  5.56                 94.44
#
# [9 rows x 25 columns]
